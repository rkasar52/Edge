# %%
import pandas as pd
import numpy as np
import random
import sklearn

# %%
df = pd.read_csv('202109-stations-capacity/all_data.csv')

# %%
df
# Out:
#            time  capacity                                            station  \
# 0       00:10.3        15                                  The Dimock Center
# 1       00:11.2        18                        Boylston St at Fairfield St
# 2       00:11.4        17                        Boylston St at Fairfield St
# 3       00:13.3        14                        Congress St at Northern Ave
# 4       00:21.2        24                    Inman Square at Springfield St.
# ...         ...       ...                                                ...
# 862139  45:24.9       105                        E Cottage St at Columbia Rd
# 862140  28:07.5        13  Christian Science Plaza - Massachusetts Ave at...
# 862141  05:12.1        27                                     Boston Landing
# 862142  41:33.2        25       Government Center - Cambridge St at Court St
# 862143  45:57.9        46                         Grove St at Community Path
#
# ...

# %%
features = ['day_of_week', 'day', 'hour', 'seconds_from_hour']

# %%
#X = df.loc[:, df.columns != 'wait_time']
X = df.loc[:, df.columns != 'decrement']
X = X[X['increment']==1]
X = X[X['wait_time']!=0]
X =X[X['station']=='Ames St at Main St']

# %%
X
# Out:
#            time  capacity             station  increment  wait_time  year  \
# 905     42:14.6         5  Ames St at Main St          1       1858  2021
# 1522    13:12.7         0  Ames St at Main St          1       1465  2021
# 1975    37:38.0        -4  Ames St at Main St          1       1559  2021
# 2393    03:37.1        -6  Ames St at Main St          1       2296  2021
# 2922    41:53.4        -7  Ames St at Main St          1        331  2021
# ...         ...       ...                 ...        ...        ...   ...
# 859932  56:21.9       638  Ames St at Main St          1        255  2021
# 860110  00:37.8       639  Ames St at Main St          1        755  2021
# 860583  13:13.4       633  Ames St at Main St          1       4675  2021
# 862089  31:09.4       632  Ames St at Main St          1         40  2021
# 862090  31:49.4       630  Ames St at Main St          1      44430  2021
#
#         month day_of_week  day  hour  minute  second  seconds_from_hour
# ...

# %%
y = X['wait_time']

# %%
X = X[features]

# %%
X_clean = pd.get_dummies(X, columns = ['day_of_week', 'day', 'hour',], drop_first = True)

# %%
X_clean
# Out:
#         seconds_from_hour  day_of_week_Monday  day_of_week_Saturday  \
# 905                  2534                   0                     0
# 1522                  792                   0                     0
# 1975                 2257                   0                     0
# 2393                  217                   0                     0
# 2922                 2513                   0                     0
# ...                   ...                 ...                   ...
# 859932               3381                   0                     0
# 860110                 37                   0                     0
# 860583                793                   0                     0
# 862089               1869                   0                     0
# 862090               1909                   0                     0
#
#         day_of_week_Sunday  day_of_week_Thursday  day_of_week_Tuesday  \
# 905                      0                     0                    0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_clean, y, 
                                                    train_size = 0.70, random_state = 1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor

# Select the model type
model = Lasso()

# Fit the model to our data
model.fit(X_train, y_train)
# Out:
# Lasso()

# %%
from sklearn import metrics
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

r2_train = metrics.r2_score(y_train, y_train_pred)
r2_test = metrics.r2_score(y_test, y_test_pred)

# %%
r2_train
# Out:
# 0.370539164580836

# %%
r2_test
# Out:
# 0.15192320703581041

# %%
y_test_pred
# Out:
# array([ 590.1633099 , 4414.83220943, -448.85237614, ..., 1322.60261489,
#          66.30093624, -332.98419694])
